# %%
github_secret = "GITHUB_PAT"
wandb_secret = "WANDB_KEY"

github_user = "instaroad"
repo_name = "InstaRoadPrototype"
branch_name = "feat-finetuning-tm"

# %%
from kaggle_secrets import UserSecretsClient
import os
import wandb

user_secrets = UserSecretsClient()

# %% [markdown]
# # Github

# %%
github_pat = user_secrets.get_secret(github_secret)

cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"
# %cd /kaggle/working
# !rm -rf /kaggle/working/{repo_name}
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}
# Out:
# /kaggle/working
# Cloning into 'InstaRoadPrototype'...
# remote: Enumerating objects: 3740, done.
# remote: Counting objects: 100% (846/846), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 3740 (delta 761), reused 719 (delta 719), pack-reused 2894 (from 2)
# Receiving objects: 100% (3740/3740), 4.77 MiB | 10.75 MiB/s, done.
# Resolving deltas: 100% (2558/2558), done.
# Submodule 'instageo' (https://github.com/InstaRoad/InstaGeo.git) registered for path 'instageo'
# Submodule 'sam_road' (https://github.com/InstaRoad/samroad.git) registered for path 'sam_road'
# Cloning into '/kaggle/working/InstaRoadPrototype/instageo'...
# remote: Enumerating objects: 2267, done.
# remote: Counting objects: 100% (570/570), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 2267 (delta 386), reused 485 (delta 370), pack-reused 1697 (from 1)
# Receiving objects: 100% (2267/2267), 11.67 MiB | 24.90 MiB/s, done.
# Resolving deltas: 100% (1411/1411), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 380 (delta 211), reused 204 (delta 202), pack-reused 138 (from 1)
# Receiving objects: 100% (380/380), 3.15 MiB | 21.93 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# Submodule path 'instageo': checked out '2926e25c3cbc4e48c6b43f9107d954f83b0eec2b'
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 6), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 18.35 KiB | 2.29 MiB/s, done.
# From https://github.com/InstaRoad/samroad
#  * branch            6e53f64d6a1d4f2d7e317341b6eb1d5747768ec0 -> FETCH_HEAD
# Submodule path 'sam_road': checked out '6e53f64d6a1d4f2d7e317341b6eb1d5747768ec0'
# Submodule 'sam' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/sam'
# Submodule 'segment-anything-road' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/segment-anything-road'
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/sam'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 31.77 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/segment-anything-road'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 21.64 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Submodule path 'sam_road/sam': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'
# Submodule path 'sam_road/segment-anything-road': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'

# %%
# !/kaggle/working/InstaRoadPrototype/src/finetuning_tm/kaggle_prep/prep_env.bash
# Out:
# Installing python dependencies...
# Requirement already satisfied: uv in /usr/local/lib/python3.12/dist-packages (0.12.1)
# Using Python 3.12.13 environment at: /usr
# Resolved 198 packages in 513ms9b0
# Prepared 1 package in 481ms
# Uninstalled 1 package in 0.61ms
# Installed 1 package in 1ms=0.1.0 (from file:///kaggle/workin
#  ~ instaroadprototype==0.1.0 (from file:///kaggle/working/InstaRoadPrototype)
# Preparing Kaggle dataset
# Using CPython 3.13.14
# Creating virtual environment at: InstaRoadPrototype/.venv
#   × No solution found when resolving dependencies for split (markers:
#   │ python_full_version >= '3.14' and platform_machine == 'x86_64' and
#   │ sys_platform == 'linux'):
#   ╰─▶ Because all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.15.1
#       depend on pyarrow>=4.0.0,<16 and mlflow>=2.16.0,<=2.17.2 depends on
#       pyarrow>=4.0.0,<18, we can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.17.2
#       depend on pyarrow>=4.0.0,<18.
#       And because mlflow>=2.18.0rc0,<=2.20.2 depends on pyarrow>=4.0.0,<19, we
#       can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.20.2
#       depend on pyarrow>=4.0.0,<19.
#       And because all of:
#           mlflow>=2.20.3,<=2.22.2
#           mlflow>=2.22.4,<=3.0.0rc2
#       depend on pyarrow>=4.0.0,<20 and all of:
#           mlflow>=3.0.0rc3,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#       depend on pyarrow>=4.0.0,<21, we can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#       depend on pyarrow>=4.0.0,<21.
#       And because mlflow>=3.2.0rc0,<=3.5.1 depends on pyarrow>=4.0.0,<22 and
#       mlflow>=3.6.0rc0,<=3.9.0 depends on pyarrow>=4.0.0,<23, we can conclude
#       that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.9.0
#       depend on pyarrow>=4.0.0,<23.
#       And because all of:
#           mlflow>=2.2.0,<=2.11.4
#           mlflow>=2.12.1,<=2.13.2
#           mlflow>=2.14.0,<=2.14.1
#           mlflow>=2.14.2,<=2.14.3
#           mlflow>=2.15.0,<=2.16.2
#           mlflow>=2.17.0,<=2.17.2
#           mlflow==2.18.0
#           mlflow==2.19.0
#           mlflow>=2.20.0,<=2.20.4
#           mlflow>=2.21.0,<=2.21.3
#           mlflow==2.22.0
#           mlflow>=3.0.0,<=3.0.1
#           mlflow>=3.1.0,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#           mlflow==3.2.0
#           mlflow>=3.3.0,<=3.3.2
#           mlflow==3.4.0
#           mlflow>=3.5.0,<=3.5.1
#           mlflow==3.6.0
#           mlflow==3.7.0
#           mlflow>=3.8.0,<=3.8.1
#           mlflow>=3.9.0,<=3.10.1
#           mlflow==3.11.0rc1
#           mlflow>=3.11.1
#       depend on pandas<3 and mlflow==3.11.0rc0 was yanked, we can conclude
#       that all of:
#           mlflow>=2.2.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.11.0rc1
#           mlflow>=3.11.1
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow>=2.0.1,<=2.1.1 depends on pyarrow>=4.0.0,<11 and
#       mlflow==2.12.0 was yanked (reason: The new build process failed to
#       include UI components), we can conclude that all of:
#           mlflow>=2.0.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.11.0rc1
#           mlflow>=3.11.1
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow==3.11.0 was yanked and mlflow==3.1.2 was yanked
#       (reason: Deployment Image Issues), we can conclude that all of:
#           mlflow>=2.0.1,<=2.22.2
#           mlflow>=2.22.4
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow==2.22.3 was yanked (reason: Missing assets) and
#       instaroadprototype[sentinel2] depends on pandas>=3.0.2, we can conclude
#       that instaroadprototype[sentinel2], mlflow>=2.0.1, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because instaroadprototype[finetuning-tm] depends on mlflow>2
#       and instaroadprototype[sentinel2] depends on pyarrow>=23.0.1,
#       we can conclude that instaroadprototype[finetuning-tm] and
#       instaroadprototype[sentinel2] are incompatible.
#       And because your project requires instaroadprototype[finetuning-tm]
#       and instaroadprototype[sentinel2], we can conclude that your project's
#       requirements are unsatisfiable.
#
# hint: While the active Python version is 3.13, the resolution failed for other Python versions supported by your project. Consider limiting your project's supported Python versions using `requires-python`.

# %% [markdown]
# # Weights and Bias Setup

# %%
wandb_api_key = user_secrets.get_secret(wandb_secret)
os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login(key=wandb_api_key)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Model Training

# %%
# %cd /kaggle/working/InstaRoadPrototype
# !python -m src.finetuning_tm.cli fit \
#     -c src/finetuning_tm/example_config.yml \
#     --trainer.max_epochs 1 \
#     --trainer.strategy ddp_find_unused_parameters_true

# %% [markdown]
# ## fit

# %%
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# !terratorch fit \
#     --config example_config.yml \
#     --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm \
#     --trainer.max_epochs 1 \
#     --trainer.strategy ddp_find_unused_parameters_true

# %% [markdown]
# ## Predict

# %%
# github_pat = user_secrets.get_secret(github_secret)

# cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"
# %cd /kaggle/working
# !rm -rf /kaggle/working/{repo_name}
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}

# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# !terratorch predict \
    --config decoder_experiments/config/dscnet_decoder.yml \
    --custom_modules_path "/kaggle/working/InstaRoadPrototype/src/finetuning_tm/custom_modules" \
    --ckpt_path "/kaggle/input/datasets/cath4444/tm-dscnet-checkpoint/model.ckpt" \
    --predict_output_dir "/kaggle/working/predictions"
# Out:
# /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Seed set to 0
# INFO:terratorch:No extra checkpoint config will be added, since the user already defined it in the callbacks.
# INFO:terratorch:Found /kaggle/working/InstaRoadPrototype/src/finetuning_tm/custom_modules
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ibm-esa-geospatial/TerraMind-1.0-tiny/resolve/main/TerraMind_v1_tiny.pt "HTTP/1.1 302 Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/ibm-esa-geospatial/TerraMind-1.0-tiny/xet-read-token/2b5ac0a3ed7dd7e922ccfd595b56607f342df343 "HTTP/1.1 200 OK"
# TerraMind_v1_tiny.pt: 100%|██████████████████| 212M/212M [00:03<00:00, 69.6MB/s]
# WARNING:terramind:Shape for encoder_embeddings.untok_sen1grd@224.pos_emb ([1, 196, 192]) does not match model weights ([1, 256, 192]), skipping weights.
# WARNING:terramind:Shape for encoder_embeddings.untok_sen2l2a@224.pos_emb ([1, 196, 192]) does not match model weights ([1, 256, 192]), skipping weights.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen2l2a@224.pos_emb are missing in state dict, using random initialization.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen1grd@224.pos_emb are missing in state dict, using random initialization.
# INFO:root:Loaded weights for RED in position 0 of patch embed
# INFO:root:Loaded weights for GREEN in position 1 of patch embed
# INFO:root:Loaded weights for BLUE in position 2 of patch embed
# INFO:root:Loaded weights for RED_EDGE_1 in position 3 of patch embed
# INFO:root:Loaded weights for RED_EDGE_2 in position 4 of patch embed
# INFO:root:Loaded weights for RED_EDGE_3 in position 5 of patch embed
# INFO:root:Loaded weights for NIR_NARROW in position 6 of patch embed
# INFO:root:Loaded weights for NIR_BROAD in position 7 of patch embed
# INFO:root:Loaded weights for SWIR_1 in position 8 of patch embed
# INFO:root:Loaded weights for SWIR_2 in position 9 of patch embed
# INFO:root:Loaded weights for VV in position 0 of patch embed
# INFO:root:Loaded weights for VH in position 1 of patch embed
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: catherinelee2004 (models-university-of-cape-town) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run a757avyl (0.3s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in wandb/run-20260804_165458-a757avyl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run serene-wood-45
# wandb: ⭐️ View project at https://wandb.ai/models-university-of-cape-town/decoder_initial_runs_rosa
# wandb: 🚀 View run at https://wandb.ai/models-university-of-cape-town/decoder_initial_runs_rosa/runs/a757avyl
# Restoring states from the checkpoint path at /kaggle/input/datasets/cath4444/tm-dscnet-checkpoint/model.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:566: The dirpath has changed from '/kaggle/working/InstaRoadPrototype/checkpoints/decoder/dscnet_decoder' to '/kaggle/working/InstaRoadPrototype/src/finetuning_tm/checkpoints/decoder/dscnet_decoder', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# Loaded model weights from the checkpoint at /kaggle/input/datasets/cath4444/tm-dscnet-checkpoint/model.ckpt
# /usr/local/lib/python3.12/dist-packages/terratorch/models/necks.py:288:  • -:--:-- 0.00it/s
# UserWarning: Cannot infer grid shape from input tokens (256), assuming a
# cls_token (default setting). Retry ReshapeTokensToImage with remove_cls_token to
# False. Silence this warning with remove_cls_token=False for neck
# ReshapeTokensToImage.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning:  0.00it/s
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing
# argument. (Triggered internally at
# /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Predicting ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/72 0:00:07 • -:--:-- 0.00it/s
# Traceback (most recent call last):
#   File "/usr/local/bin/terratorch", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/__main__.py", line 40, in main
#     _ = build_lightning_cli()
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 594, in build_lightning_cli
#     return MyLightningCLI(
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/cli.py", line 421, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/cli.py", line 759, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 941, in predict
#     return call._call_and_handle_interrupt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py", line 49, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 990, in _predict_impl
#     results = self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 1079, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 1118, in _run_stage
#     return self.predict_loop.run()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/utilities.py", line 179, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/prediction_loop.py", line 125, in run
#     self._predict_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/prediction_loop.py", line 268, in _predict_step
#     call._call_callback_hooks(trainer, "on_predict_batch_end", predictions, *hook_kwargs.values())
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py", line 228, in _call_callback_hooks
#     fn(trainer, trainer.lightning_module, *args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/prediction_writer.py", line 156, in on_predict_batch_end
#     self.write_on_batch_end(trainer, pl_module, outputs, batch_indices, batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 250, in write_on_batch_end
#     save_prediction(
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 154, in save_prediction
#     result = np.where(mask == 1, -1, prediction.detach().cpu())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: operands could not be broadcast together with shapes (512,512) () (256,256)
# Traceback (most recent call last):
#   File "/usr/local/bin/terratorch", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/__main__.py", line 40, in main
#     _ = build_lightning_cli()
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 594, in build_lightning_cli
#     return MyLightningCLI(
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/cli.py", line 421, in __init__
#     self._run_subcommand(self.subcommand)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/cli.py", line 759, in _run_subcommand
#     fn(**fn_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 941, in predict
#     return call._call_and_handle_interrupt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py", line 49, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 990, in _predict_impl
#     results = self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 1079, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/trainer.py", line 1118, in _run_stage
#     return self.predict_loop.run()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/utilities.py", line 179, in _decorator
#     return loop_run(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/prediction_loop.py", line 125, in run
#     self._predict_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/prediction_loop.py", line 268, in _predict_step
#     call._call_callback_hooks(trainer, "on_predict_batch_end", predictions, *hook_kwargs.values())
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/call.py", line 228, in _call_callback_hooks
#     fn(trainer, trainer.lightning_module, *args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/prediction_writer.py", line 156, in on_predict_batch_end
#     self.write_on_batch_end(trainer, pl_module, outputs, batch_indices, batch, batch_idx, dataloader_idx)
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 250, in write_on_batch_end
#     save_prediction(
#   File "/usr/local/lib/python3.12/dist-packages/terratorch/cli_tools.py", line 154, in save_prediction
#     result = np.where(mask == 1, -1, prediction.detach().cpu())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: operands could not be broadcast together with shapes (512,512) () (256,256)
# wandb:
# wandb: 🚀 View run serene-wood-45 at: https://wandb.ai/models-university-of-cape-town/decoder_initial_runs_rosa/runs/a757avyl

# %%
# !terratorch fit --help

# %%
# !terratorch iterate --help
