# %%
github_secret = "GITHUB_PAT"
wandb_secret = "WANDB_KEY"

github_user = "instaroad"
repo_name = "InstaRoadPrototype"
branch_name = "feat-finetuning-tm"

# %%
from kaggle_secrets import UserSecretsClient
import os
import wandb

user_secrets = UserSecretsClient()

# %% [markdown]
# # Github

# %%
github_pat = user_secrets.get_secret(github_secret)

cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"
# %cd /kaggle/working
# !rm -rf /kaggle/working/{repo_name}
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}
# Out:
# /kaggle/working
# Cloning into 'InstaRoadPrototype'...
# remote: Enumerating objects: 4126, done.
# remote: Counting objects: 100% (1232/1232), done.
# remote: Compressing objects: 100% (348/348), done.
# remote: Total 4126 (delta 1031), reused 986 (delta 884), pack-reused 2894 (from 2)
# Receiving objects: 100% (4126/4126), 4.86 MiB | 14.56 MiB/s, done.
# Resolving deltas: 100% (2828/2828), done.
# Submodule 'instageo' (https://github.com/InstaRoad/InstaGeo.git) registered for path 'instageo'
# Submodule 'sam_road' (https://github.com/InstaRoad/samroad.git) registered for path 'sam_road'
# Cloning into '/kaggle/working/InstaRoadPrototype/instageo'...
# remote: Enumerating objects: 2267, done.
# remote: Counting objects: 100% (570/570), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 2267 (delta 386), reused 485 (delta 370), pack-reused 1697 (from 1)
# Receiving objects: 100% (2267/2267), 11.67 MiB | 41.49 MiB/s, done.
# Resolving deltas: 100% (1411/1411), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 380 (delta 211), reused 204 (delta 202), pack-reused 138 (from 1)
# Receiving objects: 100% (380/380), 3.15 MiB | 33.94 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# Submodule path 'instageo': checked out '2926e25c3cbc4e48c6b43f9107d954f83b0eec2b'
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 6), reused 4 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 18.35 KiB | 3.06 MiB/s, done.
# From https://github.com/InstaRoad/samroad
#  * branch            6e53f64d6a1d4f2d7e317341b6eb1d5747768ec0 -> FETCH_HEAD
# Submodule path 'sam_road': checked out '6e53f64d6a1d4f2d7e317341b6eb1d5747768ec0'
# Submodule 'sam' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/sam'
# Submodule 'segment-anything-road' (git@github.com:htcr/segment-anything-road.git) registered for path 'sam_road/segment-anything-road'
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/sam'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 44.00 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Cloning into '/kaggle/working/InstaRoadPrototype/sam_road/segment-anything-road'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289 (from 1)
# Receiving objects: 100% (289/289), 18.30 MiB | 41.93 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# Submodule path 'sam_road/sam': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'
# Submodule path 'sam_road/segment-anything-road': checked out '6fdee8f2727f4506cfbbe553e23b895e27956588'

# %%
# !/kaggle/working/InstaRoadPrototype/src/finetuning_tm/kaggle_prep/prep_env.bash
# Out:
# Installing python dependencies...
# Collecting uv
#   Downloading uv-0.12.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.12.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 79.0 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.12.3
# Using Python 3.12.13 environment at: /usr
# Resolved 216 packages in 10.91s
# Prepared 47 packages in 2.21s
# Uninstalled 6 packages in 253ms
# Installed 47 packages in 360ms
#  + aenum==3.1.17
#  + asyncio==4.0.0
#  + databricks-sdk==0.125.0
#  + flask-cors==6.0.5
#  + ghp-import==2.1.0
#  + gputil==1.4.0
#  + graphene==3.4.3
#  + graphql-core==3.2.11
#  + graphql-relay==3.2.0
#  + griffelib==2.1.0
#  + gunicorn==26.0.0
#  + huey==3.3.4
#  + hydra-core==1.3.5
#  + instaroadprototype==0.1.0 (from file:///kaggle/working/InstaRoadPrototype)
#  + jsonargparse==4.50.0
#  + lightly==1.5.22
#  + lightly-utils==0.0.2
#  + lightning==2.6.5
#  - matplotlib==3.10.0
#  + matplotlib==3.11.1
#  + mergedeep==1.3.4
#  + mkdocs==1.6.1
#  + mkdocs-autorefs==1.4.4
#  + mkdocs-gen-files==0.6.1
#  + mkdocs-get-deps==0.2.2
#  + mkdocs-literate-nav==0.6.3
#  + mkdocstrings==1.0.6
#  + mkdocstrings-python==2.0.5
#  + mlflow==3.15.1
#  + mlflow-skinny==3.15.1
#  + mlflow-tracing==3.15.1
#  - numpy==2.0.2
#  + numpy==2.5.1
#  - opentelemetry-proto==1.38.0
#  + opentelemetry-proto==1.27.0
#  + optuna-integration==4.9.0
#  + properdocs==1.6.7
#  - protobuf==5.29.5
#  + protobuf==4.25.9
#  + pymdown-extensions==11.0.1
#  + pyyaml-env-tag==1.1
#  + rioxarray==0.23.0
#  - scikit-image==0.25.2
#  + scikit-image==0.26.0
#  + segmentation-models-pytorch==0.5.0
#  + skops==0.14.0
#  + terratorch==1.2.10 (from git+https://github.com/terrastackai/terratorch.git@375356c9ba1d919c39816abaf6b499afc303497f)
#  + terratorch-iterate==0.4
#  + torchgeo==0.9.0
#  + types-tabulate==0.10.0.20260508
#  + typeshed-client==2.13.0
#  - xarray==2025.12.0
#  + xarray==2026.7.0
# Preparing Kaggle dataset
# Using CPython 3.13.15
# Creating virtual environment at: InstaRoadPrototype/.venv
#   × No solution found when resolving dependencies for split (markers:
#   │ python_full_version >= '3.14' and platform_machine == 'x86_64' and
#   │ sys_platform == 'linux'):
#   ╰─▶ Because all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.15.1
#       depend on pyarrow>=4.0.0,<16 and mlflow>=2.16.0,<=2.17.2 depends on
#       pyarrow>=4.0.0,<18, we can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.17.2
#       depend on pyarrow>=4.0.0,<18.
#       And because mlflow>=2.18.0rc0,<=2.20.2 depends on pyarrow>=4.0.0,<19, we
#       can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.20.2
#       depend on pyarrow>=4.0.0,<19.
#       And because all of:
#           mlflow>=2.20.3,<=2.22.2
#           mlflow>=2.22.4,<=3.0.0rc2
#       depend on pyarrow>=4.0.0,<20 and all of:
#           mlflow>=3.0.0rc3,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#       depend on pyarrow>=4.0.0,<21, we can conclude that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#       depend on pyarrow>=4.0.0,<21.
#       And because mlflow>=3.2.0rc0,<=3.5.1 depends on pyarrow>=4.0.0,<22 and
#       mlflow>=3.6.0rc0,<=3.9.0 depends on pyarrow>=4.0.0,<23, we can conclude
#       that all of:
#           mlflow>=2.10.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.9.0
#       depend on pyarrow>=4.0.0,<23.
#       And because all of:
#           mlflow>=2.2.0,<=2.11.4
#           mlflow>=2.12.1,<=2.13.2
#           mlflow>=2.14.0,<=2.14.1
#           mlflow>=2.14.2,<=2.14.3
#           mlflow>=2.15.0,<=2.16.2
#           mlflow>=2.17.0,<=2.17.2
#           mlflow==2.18.0
#           mlflow==2.19.0
#           mlflow>=2.20.0,<=2.20.4
#           mlflow>=2.21.0,<=2.21.3
#           mlflow==2.22.0
#           mlflow>=3.0.0,<=3.0.1
#           mlflow>=3.1.0,<=3.1.1
#           mlflow>=3.1.3,<=3.1.4
#           mlflow==3.2.0
#           mlflow>=3.3.0,<=3.3.2
#           mlflow==3.4.0
#           mlflow>=3.5.0,<=3.5.1
#           mlflow==3.6.0
#           mlflow==3.7.0
#           mlflow>=3.8.0,<=3.8.1
#           mlflow>=3.9.0,<=3.10.1
#           mlflow==3.11.0rc1
#           mlflow>=3.11.1
#       depend on pandas<3 and mlflow==3.11.0rc0 was yanked, we can conclude
#       that all of:
#           mlflow>=2.2.0,<=2.11.4
#           mlflow>=2.12.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.11.0rc1
#           mlflow>=3.11.1
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow>=2.0.1,<=2.1.1 depends on pyarrow>=4.0.0,<11 and
#       mlflow==2.12.0 was yanked (reason: The new build process failed to
#       include UI components), we can conclude that all of:
#           mlflow>=2.0.1,<=2.22.2
#           mlflow>=2.22.4,<=3.1.1
#           mlflow>=3.1.3,<=3.11.0rc1
#           mlflow>=3.11.1
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow==3.11.0 was yanked and mlflow==3.1.2 was yanked
#       (reason: Deployment Image Issues), we can conclude that all of:
#           mlflow>=2.0.1,<=2.22.2
#           mlflow>=2.22.4
#       , pandas>=3, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because mlflow==2.22.3 was yanked (reason: Missing assets) and
#       instaroadprototype[sentinel2] depends on pandas>=3.0.2, we can conclude
#       that instaroadprototype[sentinel2], mlflow>=2.0.1, all of:
#           pyarrow<4.0.0
#           pyarrow>=23
#        are incompatible.
#       And because instaroadprototype[finetuning-tm] depends on mlflow>2
#       and instaroadprototype[sentinel2] depends on pyarrow>=23.0.1,
#       we can conclude that instaroadprototype[finetuning-tm] and
#       instaroadprototype[sentinel2] are incompatible.
#       And because your project requires instaroadprototype[finetuning-tm]
#       and instaroadprototype[sentinel2], we can conclude that your project's
#       requirements are unsatisfiable.
#
# hint: While the active Python version is 3.13, the resolution failed for other Python versions supported by your project. Consider limiting your project's supported Python versions using `requires-python`.

# %% [markdown]
# # Weights and Bias Setup

# %%
wandb_api_key = user_secrets.get_secret(wandb_secret)
os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login(key=wandb_api_key)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: catherinelee2004 (models-university-of-cape-town) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# # prototype hpo
#
# Without finetuning and with the tiny backbone
#
# Decided input: dataset normalisation statistics without enhanced rgb bands

# %% [markdown]
# ## linear_decoder

# %%
# %env MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/linear/mlflow.db
# %env CUDA_VISIBLE_DEVICES=1
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# # %cat decoder_experiments/config/hpo/hpo_dscnet.yml 
# ! terratorch iterate --hpo \
#     --config decoder_experiments/config/hpo/hpo_linear.yml \
#     --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm

# %% [markdown]
# ## dscnet_decoder

# %%
# %env MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/dscnet/mlflow.db
# %env CUDA_VISIBLE_DEVICES=1
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# %cat decoder_experiments/config/hpo/hpo_dscnet.yml 
! terratorch iterate --hpo \
    --config decoder_experiments/config/hpo/hpo_dscnet.yml \
    --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# Out:
# env: MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/dscnet/mlflow.db
# env: CUDA_VISIBLE_DEVICES=1
# /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# DEPRECATED: iterate-classic is deprecated. Please use iterate instead.
# INFO:root:Setting tracking URI: sqlite:////kaggle/working/benchmark_experiments/dscnet/mlflow.db
# INFO:root:Setting experiment name: dscnet_decoder_hpo_runs_rosa
# 2026/08/09 09:24:55 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/08/09 09:24:55 INFO mlflow.store.db.utils: Updating database tables
# 2026/08/09 09:24:57 INFO mlflow.tracking.fluent: Experiment with name 'dscnet_decoder_hpo_runs_rosa' does not exist. Creating a new experiment.
# INFO:root:Starting new experiment from scratch
# INFO:root:Running hyperparameter optimization: run_name='top_run_dscnet_decoder_hpo_runs_rosa' run_id=None description='No description provided'
# 2026/08/09 09:24:57 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# INFO:root:rosa_dscnet_decoder not completed. starting now
# INFO:root:starting backbone benchmark on task rosa_dscnet_decoder task_run_id=None experiment_name='dscnet_decoder_hpo_runs_rosa'
# INFO:root:sync_mlflow_optuna - optuna_db_path='sqlite:/kaggle/working/benchmark_experiments/dscnet/optuna_db/dscnet_decoder_hpo_runs_rosa_d83ebbe4e822499fb8d20829078df3f9' storage_uri='sqlite:////kaggle/working/benchmark_experiments/dscnet/mlflow.db' task_run_id=None experiment_name='dscnet_decoder_hpo_runs_rosa' task_run_id=None
# INFO:root:sync_mlflow_optuna returns task_run_id=None
# INFO:root:start run: run_name='rosa_dscnet_decoder' task_run_id=None
# 2026/08/09 09:24:58 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# INFO:root:starting task run with id: 8142f60263df420c88a4aa5b3689d9f1
# [I 2026-08-09 09:24:58,133] A new study created in RDB with name: rosa_dscnet_decoder
# Seed set to 42
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ibm-esa-geospatial/TerraMind-1.0-base/resolve/main/TerraMind_v1_base.pt "HTTP/1.1 302 Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/ibm-esa-geospatial/TerraMind-1.0-base/xet-read-token/fb96c70d0a5f68dcc44030b89cbfd8ec3fb0c67a "HTTP/1.1 200 OK"
# TerraMind_v1_base.pt: 100%|█████████████████| 1.52G/1.52G [00:07<00:00, 194MB/s]
# WARNING:terramind:Shape for encoder_embeddings.untok_sen1grd@224.pos_emb ([1, 196, 768]) does not match model weights ([1, 256, 768]), skipping weights.
# WARNING:terramind:Shape for encoder_embeddings.untok_sen2l2a@224.pos_emb ([1, 196, 768]) does not match model weights ([1, 256, 768]), skipping weights.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen2l2a@224.pos_emb are missing in state dict, using random initialization.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen1grd@224.pos_emb are missing in state dict, using random initialization.
# INFO:root:Loaded weights for RED in position 0 of patch embed
# INFO:root:Loaded weights for GREEN in position 1 of patch embed
# INFO:root:Loaded weights for BLUE in position 2 of patch embed
# INFO:root:Loaded weights for RED_EDGE_1 in position 3 of patch embed
# INFO:root:Loaded weights for RED_EDGE_2 in position 4 of patch embed
# INFO:root:Loaded weights for RED_EDGE_3 in position 5 of patch embed
# INFO:root:Loaded weights for NIR_NARROW in position 6 of patch embed
# INFO:root:Loaded weights for NIR_BROAD in position 7 of patch embed
# INFO:root:Loaded weights for SWIR_1 in position 8 of patch embed
# INFO:root:Loaded weights for SWIR_2 in position 9 of patch embed
# INFO:root:Loaded weights for VV in position 0 of patch embed
# INFO:root:Loaded weights for VH in position 1 of patch embed
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:root:launch_training trainer=<lightning.pytorch.trainer.trainer.Trainer object at 0x798194f30e90> task=SemanticSegmentationTask(
#   (model): PixelWiseModel(
#     (encoder): TerraMindViT(
#       (encoder_embeddings): ModuleDict(
#         (untok_sen2l2a@224): ImageEncoderEmbedding(
#           (proj): Linear(in_features=2560, out_features=768, bias=False)
#         )
#         (untok_sen1grd@224): ImageEncoderEmbedding(
#           (proj): Linear(in_features=512, out_features=768, bias=False)
#         )
#       )
#       (encoder): ModuleList(
#         (0-11): 12 x Block(
#           (norm1): LayerNorm()
#           (attn): Attention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=False)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=False)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm()
#           (mlp): GatedMlp(
#             (fc1): Linear(in_features=768, out_features=2048, bias=False)
#             (act): SiLU()
#             (fc2): Linear(in_features=2048, out_features=768, bias=False)
#             (fc3): Linear(in_features=768, out_features=2048, bias=False)
#           )
#         )
#       )
#       (encoder_norm): LayerNorm()
#       (tokenizer): ModuleDict()
#     )
#     (decoder): TerraTorchDSCNetDecoder(
#       (conv7): EncoderConv(
#         (conv): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(64, 256, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv120): EncoderConv(
#         (conv): Conv2d(1024, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv12x): DSConv(
#         (offset_conv): Conv2d(1024, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(1024, 128, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(1024, 128, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv12y): DSConv(
#         (offset_conv): Conv2d(1024, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(1024, 128, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(1024, 128, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv13): EncoderConv(
#         (conv): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(32, 128, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv140): DecoderConv(
#         (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(16, 64, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv14x): DSConv(
#         (offset_conv): Conv2d(512, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(512, 64, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(512, 64, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(16, 64, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv14y): DSConv(
#         (offset_conv): Conv2d(512, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(512, 64, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(512, 64, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(16, 64, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv15): DecoderConv(
#         (conv): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(16, 64, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv160): DecoderConv(
#         (conv): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(8, 32, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv16x): DSConv(
#         (offset_conv): Conv2d(256, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(256, 32, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(256, 32, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(8, 32, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv16y): DSConv(
#         (offset_conv): Conv2d(256, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(18, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dsc_conv_x): Conv2d(256, 32, kernel_size=(9, 1), stride=(9, 1))
#         (dsc_conv_y): Conv2d(256, 32, kernel_size=(1, 9), stride=(1, 9))
#         (gn): GroupNorm(8, 32, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (conv17): DecoderConv(
#         (conv): Conv2d(96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (gn): GroupNorm(8, 32, eps=1e-05, affine=True)
#         (relu): ReLU(inplace=True)
#       )
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#     )
#     (head): SegmentationHead(
#       (head): Sequential(
#         (0): Identity()
#         (1): Identity()
#         (2): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (aux_heads): ModuleDict()
#     (neck): NeckSequential(
#       (0): SelectIndices()
#       (1): ReshapeTokensToImage()
#       (2): LearnedInterpolateToPyramidal(
#         (fpn1): Sequential(
#           (0): ConvTranspose2d(768, 384, kernel_size=(2, 2), stride=(2, 2))
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): GELU(approximate='none')
#           (3): ConvTranspose2d(384, 192, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (fpn2): Sequential(
#           (0): ConvTranspose2d(768, 384, kernel_size=(2, 2), stride=(2, 2))
#         )
#         (fpn3): Sequential(
#           (0): Identity()
#         )
#         (fpn4): Sequential(
#           (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         )
#       )
#     )
#   )
#   (criterion): DiceLoss()
#   (train_metrics): MetricCollection(
#     (Accuracy): MulticlassAccuracy()
#     (Boundary_mIoU): BoundaryMeanIoU()
#     (Class_Accuracy): ClasswiseWrapper(
#       (metric): MulticlassAccuracy()
#     )
#     (F1_Score): MulticlassF1Score()
#     (IoU): ClasswiseWrapper(
#       (metric): MulticlassJaccardIndex()
#     )
#     (Pixel_Accuracy): MulticlassAccuracy()
#     (mIoU): MulticlassJaccardIndex()
#     (mIoU_Micro): MulticlassJaccardIndex(),
#     prefix=train/
#   )
#   (val_metrics): MetricCollection(
#     (Accuracy): MulticlassAccuracy()
#     (Boundary_mIoU): BoundaryMeanIoU()
#     (Class_Accuracy): ClasswiseWrapper(
#       (metric): MulticlassAccuracy()
#     )
#     (F1_Score): MulticlassF1Score()
#     (IoU): ClasswiseWrapper(
#       (metric): MulticlassJaccardIndex()
#     )
#     (Pixel_Accuracy): MulticlassAccuracy()
#     (mIoU): MulticlassJaccardIndex()
#     (mIoU_Micro): MulticlassJaccardIndex(),
#     prefix=val/
#   )
#   (test_metrics): ModuleList(
#     (0): MetricCollection(
#       (Accuracy): MulticlassAccuracy()
#       (Boundary_mIoU): BoundaryMeanIoU()
#       (Class_Accuracy): ClasswiseWrapper(
#         (metric): MulticlassAccuracy()
#       )
#       (F1_Score): MulticlassF1Score()
#       (IoU): ClasswiseWrapper(
#         (metric): MulticlassJaccardIndex()
#       )
#       (Pixel_Accuracy): MulticlassAccuracy()
#       (mIoU): MulticlassJaccardIndex()
#       (mIoU_Micro): MulticlassJaccardIndex(),
#       prefix=test/
#     )
#   )
# ) datamodule=<custom_modules.tm_datasets.RoadDataModule object at 0x798194eb0320> run_name='rosa_dscnet_decoder_0' experiment_name='dscnet_decoder_hpo_runs_rosa' metric='val/loss' storage_uri='sqlite:////kaggle/working/benchmark_experiments/dscnet/mlflow.db' direction='min'
# 2026/08/09 09:25:09 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ PixelWiseModel   │  100 M │ train │     0 │
# │ 1 │ criterion     │ DiceLoss         │      0 │ train │     0 │
# │ 2 │ train_metrics │ MetricCollection │      0 │ train │     0 │
# │ 3 │ val_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ test_metrics  │ ModuleList       │      0 │ train │     0 │
# └───┴───────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 100 M
# Non-trainable params: 0
# Total params: 100 M
# Total estimated model params size (MB): 402.588
# Modules in train mode: 306
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/terratorch/models/necks.py:288:
# UserWarning: Cannot infer grid shape from input tokens (256), assuming a
# cls_token (default setting). Retry ReshapeTokensToImage with remove_cls_token to
# False. Silence this warning with remove_cls_token=False for neck
# ReshapeTokensToImage.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning:
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing
# argument. (Triggered internally at
# /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43:
# UserWarning: The ``compute`` method of metric MulticlassAccuracy was called
# before the ``update`` method which may lead to errors, as metric states have not
# yet been updated.
#   warnings.warn(*args, **kwargs)
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:17:00 • 0:00:00 1.77it/s v_num: 6cc7
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2026-08-09 09:43:00,044] Trial 0 finished with value: 0.5338324308395386 and parameters: {'lr': 1.0219769972635005e-06}. Best is trial 0 with value: 0.5338324308395386.
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# INFO:root:Task                 Metric      Best Score  Hyperparameters
# -------------------  --------  ------------  ------------------------------
# rosa_dscnet_decoder  val/loss      0.533832  {'lr': 1.0219769972635005e-06}
# INFO:root:Starting to save results
# INFO:root:
# experiment_id: 1
# INFO:root:experiment_name: dscnet_decoder_hpo_runs_rosa
# INFO:root:there is at least one experiment parent run
# INFO:root:tasks that should be completed: ['rosa_dscnet_decoder']
# INFO:root:completed_task_run_names: ['rosa_dscnet_decoder']
# INFO:root:all_tasks_in_experiment_finished: True
# INFO:root:The following run FINISHED and will be used for repeated experiments: d83ebbe4e822499fb8d20829078df3f9
# INFO:root:Deleting from experiment_id:1
# INFO:root:delete_runs:[]
# INFO:root:Deleting runs:[]
# INFO:root:experiment_info.artifact_location:/kaggle/working/InstaRoadPrototype/src/finetuning_tm/mlruns/1
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 09:43:00 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# INFO:root:HPO complete

# %% [markdown]
# ## fcn_decoder

# %%
# %env MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/fcn/mlflow.db
# %env CUDA_VISIBLE_DEVICES=1
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# %cat decoder_experiments/config/hpo/hpo_dscnet.yml 
! terratorch iterate --hpo \
    --config decoder_experiments/config/hpo/hpo_fcn.yml \
    --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# Out:
# env: MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/fcn/mlflow.db
# env: CUDA_VISIBLE_DEVICES=1
# /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# DEPRECATED: iterate-classic is deprecated. Please use iterate instead.
# INFO:root:Setting tracking URI: sqlite:////kaggle/working/benchmark_experiments/fcn/mlflow.db
# INFO:root:Setting experiment name: fcn_decoder_hpo_runs_rosa
# 2026/08/09 09:43:39 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/08/09 09:43:41 INFO mlflow.store.db.utils: Updating database tables
# 2026/08/09 09:43:43 INFO mlflow.tracking.fluent: Experiment with name 'fcn_decoder_hpo_runs_rosa' does not exist. Creating a new experiment.
# INFO:root:Starting new experiment from scratch
# INFO:root:Running hyperparameter optimization: run_name='top_run_fcn_decoder_hpo_runs_rosa' run_id=None description='No description provided'
# 2026/08/09 09:43:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# INFO:root:rosa_fcn_decoder not completed. starting now
# INFO:root:starting backbone benchmark on task rosa_fcn_decoder task_run_id=None experiment_name='fcn_decoder_hpo_runs_rosa'
# INFO:root:sync_mlflow_optuna - optuna_db_path='sqlite:/kaggle/working/benchmark_experiments/fcn/optuna_db/fcn_decoder_hpo_runs_rosa_0a506409ad5d445297cd7191fcbda53d' storage_uri='sqlite:////kaggle/working/benchmark_experiments/fcn/mlflow.db' task_run_id=None experiment_name='fcn_decoder_hpo_runs_rosa' task_run_id=None
# INFO:root:sync_mlflow_optuna returns task_run_id=None
# INFO:root:start run: run_name='rosa_fcn_decoder' task_run_id=None
# 2026/08/09 09:43:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# INFO:root:starting task run with id: a90b3ff82c71467ea9ab5c05087594f0
# [I 2026-08-09 09:43:43,443] A new study created in RDB with name: rosa_fcn_decoder
# Seed set to 42
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ibm-esa-geospatial/TerraMind-1.0-base/resolve/main/TerraMind_v1_base.pt "HTTP/1.1 302 Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:terramind:Shape for encoder_embeddings.untok_sen1grd@224.pos_emb ([1, 196, 768]) does not match model weights ([1, 256, 768]), skipping weights.
# WARNING:terramind:Shape for encoder_embeddings.untok_sen2l2a@224.pos_emb ([1, 196, 768]) does not match model weights ([1, 256, 768]), skipping weights.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen1grd@224.pos_emb are missing in state dict, using random initialization.
# WARNING:terramind:Weights for encoder_embeddings.untok_sen2l2a@224.pos_emb are missing in state dict, using random initialization.
# INFO:root:Loaded weights for RED in position 0 of patch embed
# INFO:root:Loaded weights for GREEN in position 1 of patch embed
# INFO:root:Loaded weights for BLUE in position 2 of patch embed
# INFO:root:Loaded weights for RED_EDGE_1 in position 3 of patch embed
# INFO:root:Loaded weights for RED_EDGE_2 in position 4 of patch embed
# INFO:root:Loaded weights for RED_EDGE_3 in position 5 of patch embed
# INFO:root:Loaded weights for NIR_NARROW in position 6 of patch embed
# INFO:root:Loaded weights for NIR_BROAD in position 7 of patch embed
# INFO:root:Loaded weights for SWIR_1 in position 8 of patch embed
# INFO:root:Loaded weights for SWIR_2 in position 9 of patch embed
# INFO:root:Loaded weights for VV in position 0 of patch embed
# INFO:root:Loaded weights for VH in position 1 of patch embed
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:root:launch_training trainer=<lightning.pytorch.trainer.trainer.Trainer object at 0x7e695ee652b0> task=SemanticSegmentationTask(
#   (model): PixelWiseModel(
#     (encoder): TerraMindViT(
#       (encoder_embeddings): ModuleDict(
#         (untok_sen2l2a@224): ImageEncoderEmbedding(
#           (proj): Linear(in_features=2560, out_features=768, bias=False)
#         )
#         (untok_sen1grd@224): ImageEncoderEmbedding(
#           (proj): Linear(in_features=512, out_features=768, bias=False)
#         )
#       )
#       (encoder): ModuleList(
#         (0-11): 12 x Block(
#           (norm1): LayerNorm()
#           (attn): Attention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=False)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=False)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm()
#           (mlp): GatedMlp(
#             (fc1): Linear(in_features=768, out_features=2048, bias=False)
#             (act): SiLU()
#             (fc2): Linear(in_features=2048, out_features=768, bias=False)
#             (fc3): Linear(in_features=768, out_features=2048, bias=False)
#           )
#         )
#       )
#       (encoder_norm): LayerNorm()
#       (tokenizer): ModuleDict()
#     )
#     (decoder): FCNDecoder(
#       (convs): Sequential(
#         (0): Sequential(
#           (0): ConvTranspose2d(768, 512, kernel_size=(2, 2), stride=(2, 2))
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (2): Norm2d(
#             (ln): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           )
#           (3): GELU(approximate='none')
#         )
#         (1): Sequential(
#           (0): ConvTranspose2d(512, 512, kernel_size=(2, 2), stride=(2, 2))
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (2): Norm2d(
#             (ln): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           )
#           (3): GELU(approximate='none')
#         )
#         (2): Sequential(
#           (0): ConvTranspose2d(512, 512, kernel_size=(2, 2), stride=(2, 2))
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (2): Norm2d(
#             (ln): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           )
#           (3): GELU(approximate='none')
#         )
#         (3): Sequential(
#           (0): ConvTranspose2d(512, 512, kernel_size=(2, 2), stride=(2, 2))
#           (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (2): Norm2d(
#             (ln): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           )
#           (3): GELU(approximate='none')
#         )
#       )
#     )
#     (head): SegmentationHead(
#       (head): Sequential(
#         (0): Identity()
#         (1): Identity()
#         (2): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (aux_heads): ModuleDict()
#     (neck): NeckSequential(
#       (0): SelectIndices()
#       (1): ReshapeTokensToImage()
#     )
#   )
#   (criterion): DiceLoss()
#   (train_metrics): MetricCollection(
#     (Accuracy): MulticlassAccuracy()
#     (Boundary_mIoU): BoundaryMeanIoU()
#     (Class_Accuracy): ClasswiseWrapper(
#       (metric): MulticlassAccuracy()
#     )
#     (F1_Score): MulticlassF1Score()
#     (IoU): ClasswiseWrapper(
#       (metric): MulticlassJaccardIndex()
#     )
#     (Pixel_Accuracy): MulticlassAccuracy()
#     (mIoU): MulticlassJaccardIndex()
#     (mIoU_Micro): MulticlassJaccardIndex(),
#     prefix=train/
#   )
#   (val_metrics): MetricCollection(
#     (Accuracy): MulticlassAccuracy()
#     (Boundary_mIoU): BoundaryMeanIoU()
#     (Class_Accuracy): ClasswiseWrapper(
#       (metric): MulticlassAccuracy()
#     )
#     (F1_Score): MulticlassF1Score()
#     (IoU): ClasswiseWrapper(
#       (metric): MulticlassJaccardIndex()
#     )
#     (Pixel_Accuracy): MulticlassAccuracy()
#     (mIoU): MulticlassJaccardIndex()
#     (mIoU_Micro): MulticlassJaccardIndex(),
#     prefix=val/
#   )
#   (test_metrics): ModuleList(
#     (0): MetricCollection(
#       (Accuracy): MulticlassAccuracy()
#       (Boundary_mIoU): BoundaryMeanIoU()
#       (Class_Accuracy): ClasswiseWrapper(
#         (metric): MulticlassAccuracy()
#       )
#       (F1_Score): MulticlassF1Score()
#       (IoU): ClasswiseWrapper(
#         (metric): MulticlassJaccardIndex()
#       )
#       (Pixel_Accuracy): MulticlassAccuracy()
#       (mIoU): MulticlassJaccardIndex()
#       (mIoU_Micro): MulticlassJaccardIndex(),
#       prefix=test/
#     )
#   )
# ) datamodule=<custom_modules.tm_datasets.RoadDataModule object at 0x7e69649d9d90> run_name='rosa_fcn_decoder_0' experiment_name='fcn_decoder_hpo_runs_rosa' metric='val/loss' storage_uri='sqlite:////kaggle/working/benchmark_experiments/fcn/mlflow.db' direction='min'
# 2026/08/09 09:43:46 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ PixelWiseModel   │  101 M │ train │     0 │
# │ 1 │ criterion     │ DiceLoss         │      0 │ train │     0 │
# │ 2 │ train_metrics │ MetricCollection │      0 │ train │     0 │
# │ 3 │ val_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 4 │ test_metrics  │ ModuleList       │      0 │ train │     0 │
# └───┴───────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 101 M
# Non-trainable params: 0
# Total params: 101 M
# Total estimated model params size (MB): 405.919
# Modules in train mode: 248
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/terratorch/models/necks.py:288:
# UserWarning: Cannot infer grid shape from input tokens (256), assuming a
# cls_token (default setting). Retry ReshapeTokensToImage with remove_cls_token to
# False. Silence this warning with remove_cls_token=False for neck
# ReshapeTokensToImage.
#   warnings.warn(
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43:
# UserWarning: The ``compute`` method of metric MulticlassAccuracy was called
# before the ``update`` method which may lead to errors, as metric states have not
# yet been updated.
#   warnings.warn(*args, **kwargs)
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0/0  ━━━━━━━━━━━━━━━━━━━━ 1743/1743 0:42:29 • 0:00:00 0.70it/s v_num: 4992
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2026-08-09 10:27:42,697] Trial 0 finished with value: 0.35033056139945984 and parameters: {'lr': 3.000806337405348e-06}. Best is trial 0 with value: 0.35033056139945984.
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# INFO:root:Task              Metric      Best Score  Hyperparameters
# ----------------  --------  ------------  -----------------------------
# rosa_fcn_decoder  val/loss      0.350331  {'lr': 3.000806337405348e-06}
# INFO:root:Starting to save results
# INFO:root:
# experiment_id: 1
# INFO:root:experiment_name: fcn_decoder_hpo_runs_rosa
# INFO:root:there is at least one experiment parent run
# INFO:root:tasks that should be completed: ['rosa_fcn_decoder']
# INFO:root:completed_task_run_names: ['rosa_fcn_decoder']
# INFO:root:all_tasks_in_experiment_finished: True
# INFO:root:The following run FINISHED and will be used for repeated experiments: 0a506409ad5d445297cd7191fcbda53d
# INFO:root:Deleting from experiment_id:1
# INFO:root:delete_runs:[]
# INFO:root:Deleting runs:[]
# INFO:root:experiment_info.artifact_location:/kaggle/working/InstaRoadPrototype/src/finetuning_tm/mlruns/1
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/08/09 10:27:42 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# INFO:root:HPO complete

# %% [markdown]
# ## unet_decoder

# %%
# %env MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/unet/mlflow.db
# %env CUDA_VISIBLE_DEVICES=1
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# # %cat decoder_experiments/config/hpo/hpo_dscnet.yml 
# ! terratorch iterate --hpo \
#     --config decoder_experiments/config/hpo/hpo_unet.yml \
#     --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm

# %% [markdown]
# ## upernet_decoder

# %%
# %env MLFLOW_TRACKING_URI=sqlite:////kaggle/working/benchmark_experiments/upernet/mlflow.db
# %env CUDA_VISIBLE_DEVICES=1
# %cd /kaggle/working/InstaRoadPrototype/src/finetuning_tm
# # %cat decoder_experiments/config/hpo/hpo_dscnet.yml 
# ! terratorch iterate --hpo \
#     --config decoder_experiments/config/hpo/hpo_upernet.yml \
#     --custom_modules_path /kaggle/working/InstaRoadPrototype/src/finetuning_tm

# %%
# !terratorch iterate --help
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# DEPRECATED: iterate-classic is deprecated. Please use iterate instead.
# usage: terratorch [--defaults CONFIG] [--defaults.trainer_args TRAINER_ARGS]
#                   [--defaults.terratorch_task TERRATORCH_TASK]
#                   [--optimization_space OPTIMIZATION_SPACE]
#                   [--experiment_name EXPERIMENT_NAME] [--run_name RUN_NAME]
#                   [--save_models {true,false}] [--storage_uri STORAGE_URI]
#                   [--ray_storage_path RAY_STORAGE_PATH] [--n_trials N_TRIALS]
#                   [--run_repetitions RUN_REPETITIONS] [--tasks [ITEM,...]]
#                   [--parent_run_id PARENT_RUN_ID] [--output_path OUTPUT_PATH]
#                   [--logger LOGGER] [--config CONFIG]
#                   [--custom_modules_path CUSTOM_MODULES_PATH]
#                   [--report_on_best_val {true,false}]
#                   [--test_models {true,false}]
#                   [--bayesian_search {true,false}] [--hpo] [--repeat]
#                   [--continue_existing_experiments] [--summarize]
#                   [--list_of_experiment_names [ITEM,...]]
#                   [--task_names [ITEM,...]] [--task_metrics [ITEM,...]]
#                   [--benchmark_name BENCHMARK_NAME] [--build_iterate_config]
#                   [--input INPUT] [--output OUTPUT] [--template TEMPLATE]
#                   [--prefix PREFIX]
#
# options:
#   -h, --help            Show this help message and exit.
#   --optimization_space OPTIMIZATION_SPACE
#                         (type: <class 'dict'>, default: null)
#   --experiment_name EXPERIMENT_NAME
#                         (type: str, default: null)
#   --run_name RUN_NAME   (type: str, default: null)
#   --save_models {true,false}
#                         (type: bool, default: null)
#   --storage_uri STORAGE_URI
#                         (type: str, default: null)
#   --ray_storage_path RAY_STORAGE_PATH
#                         (type: str, default: null)
#   --n_trials N_TRIALS   (type: int, default: null)
#   --run_repetitions RUN_REPETITIONS
#                         (type: int, default: null)
#   --tasks.help          Show the help for Task and exit.
#   --tasks [ITEM,...], --tasks+ [ITEM,...]
#                         (type: list[Task], default: null)
#   --parent_run_id PARENT_RUN_ID
#                         (type: str, default: null)
#   --output_path OUTPUT_PATH
#                         (type: str, default: null)
#   --logger LOGGER       (type: str, default: null)
#   --config CONFIG       (type: str, default: null)
#   --custom_modules_path CUSTOM_MODULES_PATH
#                         (type: str, default: null)
#   --report_on_best_val {true,false}
#                         (type: bool, default: True)
#   --test_models {true,false}
#                         (type: bool, default: False)
#   --bayesian_search {true,false}
#                         (type: bool, default: True)
#   --hpo                 optimize hyperparameters (default: False)
#   --repeat              repeat best experiments (default: False)
#   --continue_existing_experiments
#                         continue existing experiments (default: False)
#   --summarize           summarize results from repeated experiments (default:
#                         False)
#   --list_of_experiment_names [ITEM,...], --list_of_experiment_names+ [ITEM,...]
#                         (type: list[str], default: null)
#   --task_names [ITEM,...], --task_names+ [ITEM,...]
#                         (type: list[str], default: null)
#   --task_metrics [ITEM,...], --task_metrics+ [ITEM,...]
#                         (type: list[str], default: null)
#   --benchmark_name BENCHMARK_NAME
#                         name of summarized results file (type: str, default:
#                         null)
#   --build_iterate_config
#                         convert terratorch's config into terratorch-iterate's
#                         config (default: False)
#   --input INPUT         input file or directory (type: str, default: null)
#   --output OUTPUT       output file or directory (type: str, default: null)
#   --template TEMPLATE   template for creating config files (type: str,
#                         default: null)
#   --prefix PREFIX       prefix of new config files (type: str, default: null)
#
# Default parameters set for each of the tasks:
#   --defaults CONFIG     Path to a configuration file.
#   --defaults.trainer_args TRAINER_ARGS
#                         Arguments passed to Lightning Trainer. (type:
#                         dict[str, Any], default: {})
#   --defaults.terratorch_task TERRATORCH_TASK
#                         Arguments for the Terratorch Task. (type: dict[str,
#                         Any], default: {})
