# %%
github_secret = "GITHUB_PAT"
wandb_secret = "WANDB_KEY"

github_user = "Catherine4444"
repo_name = "Adapting-and-Benchmarking-TerraMind-for-Road-Extraction"
branch_name = "main"

kaggle_dataset_dir = "/kaggle/input/datasets/cath4444/rosadataset"

# %%
from kaggle_secrets import UserSecretsClient
import os
import wandb

user_secrets = UserSecretsClient()

# %% [markdown]
# # Github

# %%
github_pat = user_secrets.get_secret(github_secret)

cmd_string = f"git clone --recursive -b {branch_name} --single-branch https://oauth2:{github_pat}@github.com/{github_user}/{repo_name}.git"
# %cd /kaggle/working
# !rm -rf /kaggle/working/{repo_name}
# !git config --global url."https://github.com/".insteadOf git@github.com:
# !{cmd_string}

# %%
# !bash /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/kaggle_prep/prep_env.bash

# %% [markdown]
# # Weights and Bias Setup

# %%
wandb_api_key = user_secrets.get_secret(wandb_secret)
os.environ["WANDB_API_KEY"] = wandb_api_key
wandb.login(key=wandb_api_key)

# %% [markdown]
# # Input Selection Results

# %% [markdown]
# ## band_norm_tm_stat_unenhance

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm
# !terratorch fit \
    --config kaggle_prototypes/prelim_experiments/config/linear_decoder.yml \
    --data kaggle_prototypes/prelim_experiments/config/norm_exp_data/band_norm_tm_stat_enhance.yml \
    --trainer.max_epochs 30 \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %% [markdown]
# ## band_norm_tm_stat_enhance

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction
# !terratorch fit \
    --config prelim_experiments/config/linear_decoder.yml \
    --data src/finetuning_tm/norm_enhance_experiments/config/band_norm_tm_stat_enhance.yml \
    --trainer.max_epochs 30 \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %% [markdown]
# ## band_norm_data_stat_unenhance

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction
# !terratorch fit \
    --config prelim_experiments/config/linear_decoder.yml \
    --data src/finetuning_tm/norm_enhance_experiments/config/band_norm_data_stat_unenhance.yml \
    --trainer.max_epochs 30 \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %% [markdown]
# ## band_norm_data_stat_enhance

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction
# !terratorch fit \
    --config prelim_experiments/config/linear_decoder.yml \
    --data src/finetuning_tm/norm_enhance_experiments/config/band_norm_data_stat_enhance.yml \
    --trainer.max_epochs 30 \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %% [markdown]
# # Effect of Reduced Precision

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm
# !terratorch fit \
    --config decoder_experiments/config/linear_decoder.yml \
    --trainer.max_epochs 1 \
    --trainer.precision "16-mixed" \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm
# !terratorch fit \
    --config decoder_experiments/config/linear_decoder.yml \
    --trainer.max_epochs 1 \
    --trainer.precision '32-true' \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"

# %% [markdown]
# # Effect of Augmentation

# %%
# %cd /kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm
# !terratorch fit \
    --config prelim_experiments/config/linear_decoder.yml \
    --data "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/prelim_experiments/config/augment_data/augmented_data.yml" \
    --custom_modules_path "/kaggle/working/Adapting-and-Benchmarking-TerraMind-for-Road-Extraction/src/finetuning_tm/custom_modules"
